# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Информация о продажах за 12 месяцев

# %%
data = {
    'Комп. мышь': np.random.normal(50, 5, 12),
    'Клавиатура': np.random.normal(67, 6, 12),
    'Видеокарта': np.random.normal(100, 7, 12),
    'Корпус': np.random.normal(48, 4, 12),
    'Монитор': np.random.normal(89, 40, 12),
    'Коврик': np.random.normal(100, 49, 12),
    'Мат. плата': np.random.normal(48, 7, 12),
    'Опер. плата': np.random.normal(75, 10, 12),
    'Провод': np.random.normal(15, 4, 12),
    'Зарядка': np.random.normal(70, 15, 12),
}

# %%
df = pd.DataFrame(data)
df
# Out:
#        Молоко       Яйца        Хлеб       Мясо        Соль       Сахар  \
# 0   53.649023  64.291265  102.742867  45.138335   84.427350  143.675071
# 1   55.126842  54.796162  102.659712  39.503222  108.280588   86.349450
# 2   49.809361  65.338214  105.217241  48.673802  149.708291  128.063355
# 3   54.222145  63.455317  111.625469  45.126682  137.701846  135.042070
# 4   49.833048  54.540157  114.026672  48.912228  106.899096  147.736962
# 5   49.991662  71.622997  100.863118  47.443815   61.708558   28.300059
# 6   47.866936  66.652143   96.131570  51.069329   91.222629  134.292076
# 7   46.814373  67.928753   96.163063  48.850835  108.691761  170.861295
# 8   46.964985  61.465777  101.144567  57.179178   26.474924  207.735677
# 9   55.935781  65.689406   99.332788  53.714008  140.345422   40.295558
# 10  55.708337  55.101896   95.661290  49.618247   48.543126   57.656897
# 11  48.672543  60.444875   98.826135  49.385307   82.793977   92.354922
#
#         Пшено     Гречка       Мыло   Сигареты
# 0   45.520696  80.905552  21.732227  93.095026
# 1   49.930199  62.158183  13.699081  61.755103
# 2   55.561930  65.132405  11.677861  79.537628
# 3   56.070516  85.425823  11.582962  96.930538
# 4   55.502079  61.477481   8.927637  68.694460
# 5   51.165066  84.808487  11.451578  72.238726
# 6   42.974019  85.511556  18.956356  64.369269
# 7   49.174472  79.315860  17.586951  97.767819
# 8   55.744550  83.181311  16.114406  69.300047
# 9   44.733599  73.947378  19.012367  82.524694
# 10  55.605442  81.920374  17.987888  65.021965
# 11  50.159713  92.867417  19.781087  43.751813

# %% [markdown]
# ## Обработка данных

# %%
ax = sns.lineplot(df)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %%
p0 = df.sum() / df.shape[0]
p0
# Out:
# Молоко       51.216253
# Яйца         62.610580
# Хлеб        102.032874
# Мясо         48.717916
# Соль         95.566464
# Сахар       114.363616
# Пшено        51.011857
# Гречка       78.054319
# Мыло         15.709200
# Сигареты     74.582257
# dtype: float64

# %%
std = ((df - p0) ** 2).sum() / (df.shape[0] - 1)
std = std ** (1 / 2)

# %%
x_extrapol = p0 + np.random.normal(0, std, len(p0))
pd.concat([df, pd.DataFrame([x_extrapol], columns=x_extrapol.index)]).reset_index(drop=True)
# Out:
#        Молоко       Яйца        Хлеб       Мясо        Соль       Сахар  \
# 0   53.649023  64.291265  102.742867  45.138335   84.427350  143.675071
# 1   55.126842  54.796162  102.659712  39.503222  108.280588   86.349450
# 2   49.809361  65.338214  105.217241  48.673802  149.708291  128.063355
# 3   54.222145  63.455317  111.625469  45.126682  137.701846  135.042070
# 4   49.833048  54.540157  114.026672  48.912228  106.899096  147.736962
# 5   49.991662  71.622997  100.863118  47.443815   61.708558   28.300059
# 6   47.866936  66.652143   96.131570  51.069329   91.222629  134.292076
# 7   46.814373  67.928753   96.163063  48.850835  108.691761  170.861295
# 8   46.964985  61.465777  101.144567  57.179178   26.474924  207.735677
# 9   55.935781  65.689406   99.332788  53.714008  140.345422   40.295558
# 10  55.708337  55.101896   95.661290  49.618247   48.543126   57.656897
# 11  48.672543  60.444875   98.826135  49.385307   82.793977   92.354922
# 12  48.578766  70.617188  102.612828  44.692790   73.164614  133.842040
#
#         Пшено     Гречка       Мыло   Сигареты
# 0   45.520696  80.905552  21.732227  93.095026
# 1   49.930199  62.158183  13.699081  61.755103
# 2   55.561930  65.132405  11.677861  79.537628
# 3   56.070516  85.425823  11.582962  96.930538
# 4   55.502079  61.477481   8.927637  68.694460
# 5   51.165066  84.808487  11.451578  72.238726
# 6   42.974019  85.511556  18.956356  64.369269
# 7   49.174472  79.315860  17.586951  97.767819
# 8   55.744550  83.181311  16.114406  69.300047
# 9   44.733599  73.947378  19.012367  82.524694
# 10  55.605442  81.920374  17.987888  65.021965
# 11  50.159713  92.867417  19.781087  43.751813
# 12  41.034738  74.434870  14.620284  82.191351

# %% [markdown]
# ## Оценки

# %%
reliability = std / p0
reliability
# Out:
# Молоко      0.067951
# Яйца        0.088125
# Хлеб        0.057340
# Мясо        0.090883
# Соль        0.394204
# Сахар       0.473630
# Пшено       0.093348
# Гречка      0.130268
# Мыло        0.260796
# Сигареты    0.215675
# dtype: float64

# %% [markdown]
# ### Уловие 1 $ X_i - \hat{p_0} < 2\hat{\sigma}: \forall i$

# %%
cond1 = ((df - p0) < 2 * std).all()
cond1
# Out:
# Молоко       True
# Яйца         True
# Хлеб        False
# Мясо         True
# Соль         True
# Сахар        True
# Пшено        True
# Гречка       True
# Мыло         True
# Сигареты     True
# dtype: bool

# %% [markdown]
# ### Условие 2 $ \hat{p_0} > 2\hat{\sigma} $

# %%
cond2 = p0 > 2 * std
cond2
# Out:
# Молоко      True
# Яйца        True
# Хлеб        True
# Мясо        True
# Соль        True
# Сахар       True
# Пшено       True
# Гречка      True
# Мыло        True
# Сигареты    True
# dtype: bool

# %% [markdown]
# ### Условие 3 $ X_i > 0: \forall i $

# %%
cond3 = (df > 0).all()
cond3
# Out:
# Молоко      True
# Яйца        True
# Хлеб        True
# Мясо        True
# Соль        True
# Сахар       True
# Пшено       True
# Гречка      True
# Мыло        True
# Сигареты    True
# dtype: bool

# %% [markdown]
# ### Цветовая классификация

# %%
product_color = pd.Series(dtype='string')
for name in df.columns:
    if (not cond3[name]):
        product_color[name] = 'Красный'
    elif (not cond1[name] and not cond2[name]):
        product_color[name] = 'Оранжевый'
    elif (not cond1[name] or not cond2[name]):
        product_color[name] = 'Желтый'
    else:
        product_color[name] = 'Зеленый'
product_color
# Out:
# Молоко      Зеленый
# Яйца        Зеленый
# Хлеб         Желтый
# Мясо        Зеленый
# Соль        Зеленый
# Сахар       Зеленый
# Пшено       Зеленый
# Гречка      Зеленый
# Мыло        Зеленый
# Сигареты    Зеленый
# dtype: object
